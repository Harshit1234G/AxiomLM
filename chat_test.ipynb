# %%
from pathlib import Path
import tensorflow as tf
import sys

axiom_utils = Path('kaggle/input/datasets/harshit1234g/axiomlm-utils')
sys.path.append(str(axiom_utils))
import llm_components as lc

# %%
sp = lc.load_sp_tokenizer(str(axiom_utils / 'sp_tokenizer.model'))

# %%
model = tf.keras.models.load_model('kaggle/working/AxiomLM-33M-Instruct.keras')
# Out:
# WARNING:tensorflow:From e:\my_research\AxiomLM\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# e:\my_research\AxiomLM\.venv\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adamw', because it has 186 variables whereas the saved optimizer has 94 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
while True:
    prompt = input('Enter your prompt: ')
    if prompt.lower().strip() == 'quit':
        break

    formatted_prompt = f'# Instruction:\n{prompt}\n# Response:\n'
    generated_text = lc.generate_text(
        model,
        tokenizer= sp,
        prompt= formatted_prompt,
        max_new_tokens= 200,
        temperature= 0.8
    )
    response = generated_text.split('# Response:')[1]
    print(f'Response: {response}\n')
# Out:
# Response:  HeadilyMultiple Songs RepresentSoon after the release of Virgin Australia and the subsequent demographics albums (with singles except single releases), The Black Eyed Peas (1983) and Dip Records (with singles such as"A Day on the Wall"), have since come to be called"The Black Eyed Peas". In 1984 the UK - based group The Black Eyed Peas was founded in the United Kingdom and features themselves as a group based on their success. One of the first acts from the new wave of music to a wider audience have been"White."In 2011 it was reported that a new wave of artists like The Black Eyed Peas was created, and will be the first successful group to achieve their biggest hits,"The Black Eyed Peas (V.C.)"(1983). Invasion
#
# ...
