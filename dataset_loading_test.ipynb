# %%
import tensorflow as tf
import sentencepiece as spm

# %%
sp = spm.SentencePieceProcessor()
sp.load('sp_tokenizer.model')
# Out:
# True

# %%
def sp_tokenize(line: tf.Tensor) -> tf.Tensor:
    tokens = sp.encode(line.numpy().decode('utf-8'), out_type= int)
    return tf.constant(tokens, dtype= tf.int32)

# %%
line = tf.constant(b'Hello world')
sp_tokenize(line)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 6740, 15920,  1036], dtype=int32)>

# %%
line.numpy().decode('utf-8')
# Out:
# 'Hello world'

# %%
def tf_sp_tokenize(line: tf.Tensor) -> tf.Tensor:
    tokens = tf.py_function(
        func= sp_tokenize,
        inp= [line], 
        Tout= tf.int32
    )
    tokens.set_shape([None])
    return tokens

# %%
tf_sp_tokenize(line)
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([ 6740, 15920,  1036], dtype=int32)>

# %%
AUTOTUNE = tf.data.AUTOTUNE
ds = tf.data.TextLineDataset('kaggle/input/wikitext-103/wikitext-103/wiki.train.tokens')

# %%
def print_data(num: int = 2) -> None:
    for item in ds.take(num):
        print(item)

# %%
print_data()
# Out:
# tf.Tensor(b' ', shape=(), dtype=string)
# tf.Tensor(b' = Valkyria Chronicles III = ', shape=(), dtype=string)

# %%
ds = ds.map(
    tf_sp_tokenize,
    num_parallel_calls= AUTOTUNE
)
print_data()
# Out:
# tf.Tensor([], shape=(0,), dtype=int32)
# tf.Tensor([   48   250  1288 15933  3199  7429   408  3282    48], shape=(9,), dtype=int32)

# %%
ds = ds.flat_map(
    lambda x: tf.data.Dataset.from_tensor_slices(x)
)
print_data(10)
# Out:
# tf.Tensor(48, shape=(), dtype=int32)
# tf.Tensor(250, shape=(), dtype=int32)
# tf.Tensor(1288, shape=(), dtype=int32)
# tf.Tensor(15933, shape=(), dtype=int32)
# tf.Tensor(3199, shape=(), dtype=int32)
# tf.Tensor(7429, shape=(), dtype=int32)
# tf.Tensor(408, shape=(), dtype=int32)
# tf.Tensor(3282, shape=(), dtype=int32)
# tf.Tensor(48, shape=(), dtype=int32)
# tf.Tensor(2471, shape=(), dtype=int32)

# %%
ds = ds.batch(8 + 1, drop_remainder= True)
print_data()
# Out:
# tf.Tensor([   48   250  1288 15933  3199  7429   408  3282    48], shape=(9,), dtype=int32)
# tf.Tensor([ 2471 15977     0   671   250  1288 15933  3199   233], shape=(9,), dtype=int32)

# %%
ds = ds.map(
    lambda x: (x[:-1], x[1:]),
    num_parallel_calls= tf.data.AUTOTUNE
)
print_data(1)
# Out:
# (<tf.Tensor: shape=(8,), dtype=int32, numpy=
# array([   48,   250,  1288, 15933,  3199,  7429,   408,  3282],
#       dtype=int32)>, <tf.Tensor: shape=(8,), dtype=int32, numpy=
# array([  250,  1288, 15933,  3199,  7429,   408,  3282,    48],
#       dtype=int32)>)

# %%
ds = ds.batch(8)
print_data(1)
# Out:
# (<tf.Tensor: shape=(8, 8, 8), dtype=int32, numpy=
# array([[[   48,   250,  1288, 15933,  3199,  7429,   408,  3282],
#         [ 2471, 15977,     0,   671,   250,  1288, 15933,  3199],
#         [  281, 15914,     0,  2149,     0,  7429,   408,   119],
#         [  281, 15914,     0, 15967,    11,  1156,    19,   250],
#         [15933,  3199,    29,     8,  2132,  1825,   233,   118],
#         [ 5037,  3353,    37,    92,   250,  1288, 15933,  3199],
#         [  408,  3282,  2524,  1150,    11,   120,     6, 12694],
#         [   83,  2014,  1296,   481,  1699,   113, 10082,    36]],
#
#        [[15936, 15981,   566,    84,     8,  5213,  2112,   411],
#         [ 6337,   413,    31,  1113,  1361,    31,  1150,    11],
#         [  120,     8,  1093,   481,    31,     8,   250,  1288],
#         [ 3199,   687,    19,  1871,  1613,    33,     8,   905],
#         [   29, 12694,    36,  1324,    83,   390,  5521,    92],
#         [13841,    11,     8,  1160,  2194,  5399,    37,     8],
#         [  481,    36,  4563,     8,    53, 12178,  5936,    53],
#         [    6,  6185,  1628,  3535,  4630,     8,  3731,    29]],
#
#        [[  228,   474,     8,  2817,  1231,    30,   787,   305],
#         [ 3388,  1817,  3036,    36,   214,    34,  1723,   641],
#         [ 5724,  3535,    53, 15914,     0,  2149,     0,   106],
#         [   53,    19,    72,   481,   792,  1655,    31,  1279],
#         [ 5710,   346,     6,  1075,  3890,    29,     8,   431],
#         [   69,   250,  1288, 15933,  3199,  7429,   408,  1123],
#         [ 1525,   134,  5771,     8,  3384,  1927,    29,     8],
#         [   11,   134,   285,  9420,  3857, 12204,   852,    11]],
#
#        [[   92,  1618,     8,   481,   430,  9207,  1003,    84],
#         [  442,  2569,   126,    19, 12968,  7554, 15914,     0],
#         [    0,  5244, 15977,    45,    36,  6123,  5015, 13741],
#         [   80,  7539,   686,  1531,   148,  1173, 14945,    11],
#         [  103,   250,  1288, 15933,  3199,  7429,   408,  1123],
#         [   46,  1354,  4787,   149, 15976,  5504,    19,    51],
#         [  602,    29,  3943,  9668,     8,  2912,    19,    72],
#         [   74, 15922,  2310,  3581,    67,  8773,   113,   845]],
#
#        [[15918,    19,   365,   725,   103,  2508,  3321,    31],
#         [   11,    36,    67,  2413,   113,   686,  1764,    36],
#         [ 2184,    19,   652,  1278,    11,   134,   962,  5964],
#         [ 4184,    11,   856,   103,   132,  4943,  3643,    31],
#         [   29,   105,   350,    19,   365,    67,   285,  5941],
#         [ 9880,    36,   132,  1253,  1296,  7331,   687,    19],
#         [   37,  1511,  3321,    29,   250,  1288, 15933,  3199],
#         [  408,  1123,    11,   250,  1288, 15933,  3199,  7429]],
#
#        [[ 3282,    67,   218,  1359,   830,    11,   245,     6],
#         [ 9417, 13581,   903,   103,     8,   481,    74, 15922],
#         [ 3643,    67,   824,    31,  1803,    19,  6386, 15936],
#         [  566,   387,   791,    37,     8,  5478,   103,     8],
#         [   29,   250,  1288, 15933,  3199,   281,  6593,   259],
#         [   84,     8,  5213,   298,    19,    48,    48, 14210],
#         [   48,   484,   103,  1173, 15914,     0,  2149,     0],
#         [  408,  1209,    11,   250,  1288, 15933,  3199,  7429]],
#
#        [[ 3282,   120,     6, 12694,  1308,    83,  2014,   481],
#         [ 1802,  1405,  1321,    29,     6,  1628,  3535,    36],
#         [  329,    31,  6469,   641,  3872,  1596,    19, 12870],
#         [ 2534,   529,  5304,  1087,    83,   921, 12769,   103],
#         [  912, 15876,    11,   103,  1687,  6491,  7594,   529],
#         [ 4414,    28,  6366,   408,    36,  7594,   529,   239],
#         [ 4219,  3664,    19,    72,  1449,  4831,    26,   529],
#         [  687,    29, 11801,  6469,    11,  5850,  6134,  4449]],
#
#        [[10885,   105,   510,   104, 14763,   310,  2360,   529],
#         [ 1205,    96,    14,    92,   371,   214,  6134,  4449],
#         [   72,  1910,    37,   979,  1160,  3159,    69,     8],
#         [11887,  8413,    69,   132,  3243,  1449,    74, 15922],
#         [  281,   448,   306,  7887,   120,  3366,    11,     8],
#         [  120,   172,  2293,   358,    37,     8,  1449,    19],
#         [ 6469,    11,     8,  1449,  1687,  1034,    31,     6],
#         [   11,   554,  2445,   510,   104,  7993,   830,    36]]],
#       dtype=int32)>, <tf.Tensor: shape=(8, 8, 8), dtype=int32, numpy=
# array([[[  250,  1288, 15933,  3199,  7429,   408,  3282,    48],
#         [15977,     0,   671,   250,  1288, 15933,  3199,   233],
#         [15914,     0,  2149,     0,  7429,   408,   119,  1764],
#         [15914,     0, 15967,    11,  1156,    19,   250,  1288],
#         [ 3199,    29,     8,  2132,  1825,   233,   118,    11],
#         [ 3353,    37,    92,   250,  1288, 15933,  3199,  7429],
#         [ 3282,  2524,  1150,    11,   120,     6, 12694,  1308],
#         [ 2014,  1296,   481,  1699,   113, 10082,    36,  6386]],
#
#        [[15981,   566,    84,     8,  5213,  2112,   411,    19],
#         [  413,    31,  1113,  1361,    31,  1150,    11,   134],
#         [    8,  1093,   481,    31,     8,   250,  1288, 15933],
#         [  687,    19,  1871,  1613,    33,     8,   905, 13712],
#         [12694,    36,  1324,    83,   390,  5521,    92,   271],
#         [   11,     8,  1160,  2194,  5399,    37,     8,   265],
#         [   36,  4563,     8,    53, 12178,  5936,    53,    11],
#         [ 6185,  1628,  3535,  4630,     8,  3731,    29,  4789]],
#
#        [[  474,     8,  2817,  1231,    30,   787,   305,   667],
#         [ 1817,  3036,    36,   214,    34,  1723,   641,     8],
#         [ 3535,    53, 15914,     0,  2149,     0,   106,  4157],
#         [   19,    72,   481,   792,  1655,    31,  1279,    11],
#         [  346,     6,  1075,  3890,    29,     8,   431,  3004],
#         [  250,  1288, 15933,  3199,  7429,   408,  1123,    19],
#         [  134,  5771,     8,  3384,  1927,    29,     8,   687],
#         [  134,   285,  9420,  3857, 12204,   852,    11,   584]],
#
#        [[ 1618,     8,   481,   430,  9207,  1003,    84,   687],
#         [ 2569,   126,    19, 12968,  7554, 15914,     0,  2149],
#         [ 5244, 15977,    45,    36,  6123,  5015, 13741,  9210],
#         [ 7539,   686,  1531,   148,  1173, 14945,    11,   856],
#         [  250,  1288, 15933,  3199,  7429,   408,  1123,  2319],
#         [ 1354,  4787,   149, 15976,  5504,    19,    51,  1075],
#         [   29,  3943,  9668,     8,  2912,    19,    72,   481],
#         [15922,  2310,  3581,    67,  8773,   113,   845,    74]],
#
#        [[   19,   365,   725,   103,  2508,  3321,    31,  1150],
#         [   36,    67,  2413,   113,   686,  1764,    36,  2713],
#         [   19,   652,  1278,    11,   134,   962,  5964,   411],
#         [   11,   856,   103,   132,  4943,  3643,    31,  1030],
#         [  105,   350,    19,   365,    67,   285,  5941,   391],
#         [   36,   132,  1253,  1296,  7331,   687,    19,  4868],
#         [ 1511,  3321,    29,   250,  1288, 15933,  3199,  7429],
#         [ 1123,    11,   250,  1288, 15933,  3199,  7429,   408]],
#
#        [[   67,   218,  1359,   830,    11,   245,     6,  4669],
#         [13581,   903,   103,     8,   481,    74, 15922,  4943],
#         [   67,   824,    31,  1803,    19,  6386, 15936, 15981],
#         [  387,   791,    37,     8,  5478,   103,     8,  1655],
#         [  250,  1288, 15933,  3199,   281,  6593,   259,  4867],
#         [    8,  5213,   298,    19,    48,    48, 14210,    48],
#         [  484,   103,  1173, 15914,     0,  2149,     0,  7429],
#         [ 1209,    11,   250,  1288, 15933,  3199,  7429,   408]],
#
#        [[  120,     6, 12694,  1308,    83,  2014,   481,   554],
#         [ 1405,  1321,    29,     6,  1628,  3535,    36,  1405],
#         [   31,  6469,   641,  3872,  1596,    19, 12870,   214],
#         [  529,  5304,  1087,    83,   921, 12769,   103,  6438],
#         [15876,    11,   103,  1687,  6491,  7594,   529,  8089],
#         [   28,  6366,   408,    36,  7594,   529,   239, 13762],
#         [ 3664,    19,    72,  1449,  4831,    26,   529,     6],
#         [   29, 11801,  6469,    11,  5850,  6134,  4449,    92]],
#
#        [[  105,   510,   104, 14763,   310,  2360,   529,    36],
#         [   96,    14,    92,   371,   214,  6134,  4449,    19],
#         [ 1910,    37,   979,  1160,  3159,    69,     8,  7113],
#         [ 8413,    69,   132,  3243,  1449,    74, 15922,  3182],
#         [  448,   306,  7887,   120,  3366,    11,     8,   374],
#         [  172,  2293,   358,    37,     8,  1449,    19, 14189],
#         [   11,     8,  1449,  1687,  1034,    31,     6,  1135],
#         [  554,  2445,   510,   104,  7993,   830,    36,   912]]],
#       dtype=int32)>)
